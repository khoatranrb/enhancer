# %%
import torch
import models
import cv2
import numpy as np
import dataloader
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# 1.6.0
# 1.6.0

# %%
dped = models.DPED()
# curl = torch.nn.DataParallel(curl)
# orig_model = '/home/kt/Desktop/enhancer/checkpoints/CURL/DPED_data/0_sony_25.276445812446095_0.9373145998418331.pth'
# curl.load_state_dict(torch.load(orig_model), strict=True)
dped.eval()
# Out:
# DPED(
#   (conv1): Conv2d(3, 64, kernel_size=(9, 9), stride=(1, 1), padding=(4, 4))
#   (block1): ConvBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (instance_norm1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (instance_norm2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (relu1): ReLU()
#     (relu2): ReLU()
#   )
#   (block2): ConvBlock(
#     (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (instance_norm1): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (instance_norm2): InstanceNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=False)
#     (relu1): ReLU()
#     (relu2): ReLU()
#   )
# ...

# %%
dped_dataset = dataloader.LoadDPED(phone='sony', dataset_size=5, test=True)
dataset = DataLoader(dataset=dped_dataset, batch_size=1, shuffle=False, num_workers=1,
                             pin_memory=True, drop_last=False)

# %%
adobe_dataset = dataloader.LoadAdobe(dataset_size=5)
dataset = DataLoader(dataset=adobe_dataset, batch_size=1, shuffle=False, num_workers=1,
                             pin_memory=True, drop_last=False)

# %%
# print(dped_dataset.inp_dir)
for x, y in iter(dataset):
    x = x.numpy()[0].transpose((1,2,0))
    y = y.numpy()[0].transpose((1,2,0))
    print(x.shape)
    plt.imshow(x[:,:,[2,1,0]])
    plt.show()
    plt.imshow(y[:,:,[2,1,0]])
    plt.show()
#     break
# Out:
# (332, 500, 3)
# (332, 500, 3)
# (500, 333, 3)
# (500, 333, 3)
# (333, 500, 3)
